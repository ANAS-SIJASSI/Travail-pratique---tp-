# %%
# File location and type
file_location = "/FileStore/tables/201802_fordgobike_tripdata.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a view or table

temp_table_name = "201802_fordgobike_tripdata_csv"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `201802_fordgobike_tripdata_csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "201802_fordgobike_tripdata_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
Tripdata = spark.read.csv("/FileStore/tables/201802_fordgobike_tripdata.csv", header="true", inferSchema="true")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#we use columns dataFram attribute to see our columns
Tripdata.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: [&#39;duration_sec&#39;,
#  &#39;start_time&#39;,
#  &#39;end_time&#39;,
#  &#39;start_station_id&#39;,
#  &#39;start_station_name&#39;,
#  &#39;start_station_latitude&#39;,
#  &#39;start_station_longitude&#39;,
#  &#39;end_station_id&#39;,
#  &#39;end_station_name&#39;,
#  &#39;end_station_latitude&#39;,
#  &#39;end_station_longitude&#39;,
#  &#39;bike_id&#39;,
#  &#39;user_type&#39;,
#  &#39;bike_share_for_all_trip&#39;]</div>

# %%
#we se that our start_time and end_time is not an date type , we will change them to date type
Tripdata.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[136]: [(&#39;duration_sec&#39;, &#39;int&#39;),
#  (&#39;start_time&#39;, &#39;string&#39;),
#  (&#39;end_time&#39;, &#39;string&#39;),
#  (&#39;start_station_id&#39;, &#39;int&#39;),
#  (&#39;start_station_name&#39;, &#39;string&#39;),
#  (&#39;start_station_latitude&#39;, &#39;double&#39;),
#  (&#39;start_station_longitude&#39;, &#39;double&#39;),
#  (&#39;end_station_id&#39;, &#39;int&#39;),
#  (&#39;end_station_name&#39;, &#39;string&#39;),
#  (&#39;end_station_latitude&#39;, &#39;double&#39;),
#  (&#39;end_station_longitude&#39;, &#39;double&#39;),
#  (&#39;bike_id&#39;, &#39;int&#39;),
# ...

# %%
Tripdata.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+--------------------+--------------------+----------------+--------------------+----------------------+-----------------------+--------------+--------------------+--------------------+---------------------+-------+----------+-----------------------+
# duration_sec|          start_time|            end_time|start_station_id|  start_station_name|start_station_latitude|start_station_longitude|end_station_id|    end_station_name|end_station_latitude|end_station_longitude|bike_id| user_type|bike_share_for_all_trip|
# ...

# %%
# Print the schema in a tree format
Tripdata.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- duration_sec: integer (nullable = true)
# -- start_time: string (nullable = true)
# -- end_time: string (nullable = true)
# -- start_station_id: integer (nullable = true)
# -- start_station_name: string (nullable = true)
# -- start_station_latitude: double (nullable = true)
# -- start_station_longitude: double (nullable = true)
# -- end_station_id: integer (nullable = true)
# -- end_station_name: string (nullable = true)
# -- end_station_latitude: double (nullable = true)
# -- end_station_longitude: double (nullable = true)
# -- bike_id: integer (nullable = true)
# -- user_type: string (nullable = true)
# ...

# %%
from pyspark.sql.types import DateType
Tripdata = Tripdata.withColumn("start_time", Tripdata['start_time'].cast(DateType())) \
    .withColumn('end_time', Tripdata['end_time'].cast(DateType()))
Tripdata.show()
Tripdata.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+----------+----------+----------------+--------------------+----------------------+-----------------------+--------------+--------------------+--------------------+---------------------+-------+----------+-----------------------+
# duration_sec|start_time|  end_time|start_station_id|  start_station_name|start_station_latitude|start_station_longitude|end_station_id|    end_station_name|end_station_latitude|end_station_longitude|bike_id| user_type|bike_share_for_all_trip|
# ...

# %%
# we see that the type of start_time/end_time changed from string --> date
Tripdata.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- duration_sec: integer (nullable = true)
# -- start_time: date (nullable = true)
# -- end_time: date (nullable = true)
# -- start_station_id: integer (nullable = true)
# -- start_station_name: string (nullable = true)
# -- start_station_latitude: double (nullable = true)
# -- start_station_longitude: double (nullable = true)
# -- end_station_id: integer (nullable = true)
# -- end_station_name: string (nullable = true)
# -- end_station_latitude: double (nullable = true)
# -- end_station_longitude: double (nullable = true)
# -- bike_id: integer (nullable = true)
# -- user_type: string (nullable = true)
# ...

# %%
Tripdata.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[141]: DataFrame[summary: string, duration_sec: string, start_station_id: string, start_station_name: string, start_station_latitude: string, start_station_longitude: string, end_station_id: string, end_station_name: string, end_station_latitude: string, end_station_longitude: string, bike_id: string, user_type: string, bike_share_for_all_trip: string]</div>

# %%
display(Tripdata.select('duration_sec'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('duration_sec'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('start_station_id'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('start_station_id'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Plotting end station id distribution.


display(Tripdata.select('end_station_id')).plot
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('end_station_id'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# plotting types of users on bar.


display(Tripdata.select('user_type'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('user_type'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# plotting bike_share_for_all_trip  on bar.


display(Tripdata.select('bike_share_for_all_trip'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(Tripdata.select('bike_share_for_all_trip'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
